# %%
player_database_pgn = open(
        "\\rajakel_all_games.pgn"
    )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 player_database_pgn = open(
#       2         "\\rajakel_all_games.pgn"
#       3     )
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\rajakel_all_games.pgn'
